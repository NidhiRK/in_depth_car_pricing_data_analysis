# %% [markdown]
# ## **Imports libraris**

# %%
import pandas as pd # use for data Manipulating
from matplotlib import pyplot as plt # use for visualization
import seaborn as sns
import plotly.express as px # for data visualization i.e provides function to analys and visualize data
import warnings
warnings.simplefilter(action = 'ignore',category = FutureWarning)

# %% [markdown]
# ## **DATA collection**

# %%
data_frame = pd.read_csv("car_prices.csv")
data_frame# data_frame --> It will show all the col and row in df(data_frame)
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
data_frame.head() # head()--> used to display the only 1st 5 row from the data_frame(by default)
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %% [markdown]
# ## **DATA Exproling**

# %%
data_frame.head(1)
# Out:
#    year make    model trim body transmission                vin state  \
# 0  2015  Kia  Sorento   LX  SUV    automatic  5xyktca69fg566472    ca
#
#    condition  odometer  color interior                   seller      mmr  \
# 0        5.0   16639.0  white    black  kia motors america  inc  20500.0
#
#    sellingprice                                 saledate
# 0       21500.0  Tue Dec 16 2014 12:30:00 GMT-0800 (PST)

# %%
data_frame.shape # shape --> showa to total number of row and columns from the dataset
# Out:
# (558837, 16)

# %%
data_frame.columns # columns --> use to show all columns name from data set
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
data_frame.info() #info() --> it will show information about the data set like (data types)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
data_frame['saledate'] = pd.to_datetime(data_frame['saledate'], format='%Y-%m-%d', errors='coerce')

# %%
data_frame['saledate'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 558837 entries, 0 to 558836
# Series name: saledate
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 4.3 MB

# %%
data_frame.nunique() # nunique() --> It's use to show the number of total unique value of the col from data set
# Out:
# year                34
# make                96
# model              973
# trim              1963
# body                87
# transmission         4
# vin             550297
# state               64
# condition           41
# odometer        172278
# color               46
# interior            17
# seller           14263
# mmr               1101
# sellingprice      1887
# saledate             0
# dtype: int64

# %%
data_frame["year"].unique
# Out:
# <bound method Series.unique of 0         2015
# 1         2015
# 2         2014
# 3         2015
# 4         2014
#           ...
# 558832    2015
# 558833    2012
# 558834    2012
# 558835    2015
# 558836    2014
# Name: year, Length: 558837, dtype: int64>

# %%
data_frame.count() # count() --> use to count the all value of the col
# Out:
# year            558837
# make            548536
# model           548438
# trim            548186
# body            545642
# transmission    493485
# vin             558833
# state           558837
# condition       547017
# odometer        558743
# color           558088
# interior        558088
# seller          558837
# mmr             558799
# sellingprice    558825
# saledate             0
# dtype: int64

# %%
data_frame.describe() # describe --> use to generate statistics for numerical columns in the data frame such as
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
# std         3.966864      13.402832   53398.542821    9679.967174
#
#         sellingprice saledate
# count  558825.000000        0
# mean    13611.358810      NaT
# min         1.000000      NaT
# 25%      6900.000000      NaT
# 50%     12100.000000      NaT
# 75%     18200.000000      NaT
# max    230000.000000      NaT
# std      9749.501628      NaN

# %% [markdown]
# ## **Feature Engeneering**

# %%
data_frame['year'] = pd.to_datetime(data_frame['year'], format='%Y')
current_year = pd.Timestamp.now().year
data_frame['car_age'] = current_year - data_frame['year'].dt.year

# %%
data_frame['car_age']
# Out:
# 0          9
# 1          9
# 2         10
# 3          9
# 4         10
#           ..
# 558832     9
# 558833    12
# 558834    12
# 558835     9
# 558836    10
# Name: car_age, Length: 558837, dtype: int32

# %%
# Display the updated DataFrame with 'car_age'
print(data_frame[['year', 'car_age']].head())
# Out:
#         year  car_age
# 0 2015-01-01        9
# 1 2015-01-01        9
# 2 2014-01-01       10
# 3 2015-01-01        9
# 4 2014-01-01       10

# %% [markdown]
# ## **DATA Cleaning**

# %%
data_frame.isnull().sum()    #is use to detect missing or nan values
# Out:
# year                 0
# make             10301
# model            10399
# trim             10651
# body             13195
# transmission     65352
# vin                  4
# state                0
# condition        11820
# odometer            94
# color              749
# interior           749
# seller               0
# mmr                 38
# sellingprice        12
# saledate        558837
# car_age              0
# dtype: int64

# %%
sns.heatmap(data_frame.isnull())
# Out:
# <Axes: >

# %%
data_frame.duplicated().sum()
# Out:
# 0

# %%
# Handling missing values
df = data_frame.fillna(data_frame['sellingprice'].mean())  # Drop rows with missing values 
# Or fill missing values with appropriate methods like mean, median, or mode

# Removing duplicates
data_frame.drop_duplicates(inplace=True)

# Handling inconsistent data
# This might involve standardizing text data, correcting erroneous values, etc.

# %%
df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# car_age         0
# dtype: int64

# %% [markdown]
# ## **OUTLIRE DITECTION AND REMOVING**

# %%
plt.figure(figsize = (12,6))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
for i in ['year','odometer','mmr','sellingprice']:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[i] < upper_bound ) & (df[i] > lower_bound )]

# %%
plt.figure(figsize = (12,6))
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
print(len(data_frame))
# Out:
# 558837

# %%
print(len(df))
# Out:
# 524421

# %%
print(len(data_frame) - len(df))
# Out:
# 34416

# %%
sns.boxplot(data = df["sellingprice"])
# Out:
# <Axes: >

# %%
sns.boxplot(data = data_frame["sellingprice"])
# Out:
# <Axes: >

# %%
for i in ['year','odometer','mmr','sellingprice']:
    upper_bound = df[i].mean() + 3 * df[i].std()
    lower_bound = df[i].mean() - 3 * df[i].std()
    outlire = df[(df[i]<upper_bound) & (df[i]>lower_bound)]

# %%
plt.figure(figsize = (12,6))
sns.boxplot(outlire)
# Out:
# <Axes: >

# %%
print(len(data_frame) - len(outlire))
# Out:
# 34416

# %%
print(len(outlire))
# Out:
# 524421

# %%
# plt.boxplot(outlire['year'])

# %%
sns.boxplot(data = outlire['mmr'])
# Out:
# <Axes: >

# %%
sns.boxplot(data_frame['mmr'])
# Out:
# <Axes: >

# %% [markdown]
# ## DATA FILTRING

# %%
df.loc[df['sellingprice'] > 25000, ['make','sellingprice']].head()
# Out:
#      make  sellingprice
# 2     BMW       30000.0
# 3   Volvo       27750.0
# 8    Audi       32250.0
# 21    BMW       30000.0
# 26  Volvo       32500.0

# %%
df.loc[data_frame['sellingprice'] == 30000.0]
# Out:
#              year       make     model        trim      body transmission  \
# 2      2014-01-01        BMW  3 Series  328i SULEV     Sedan    automatic
# 21     2014-01-01        BMW  5 Series        528i     Sedan    automatic
# 43     2015-01-01      Volvo       V60          T5     Wagon    automatic
# 46     2015-01-01      Volvo       V60          T5     Wagon    automatic
# 50     2015-01-01      Volvo       V60          T5     Wagon    automatic
# ...           ...        ...       ...         ...       ...          ...
# 557591 2011-01-01        BMW        X5   xDrive35i       suv  13611.35881
# 558311 2011-01-01  Chevrolet     Tahoe          LT       suv    automatic
# 558357 2009-01-01  Chevrolet  Suburban    1500 LTZ       suv  13611.35881
# 558369 2009-01-01    Pontiac        G8         GXP     sedan  13611.35881
# 558491 2014-01-01     Nissan  Frontier      PRO-4X  crew cab    automatic
#
#                       vin state  condition  odometer     color interior  \
# ...

# %%
df.groupby('state')['sellingprice'].sum().sort_values(ascending = True).head()
# Out:
# state
# 3vwd17aj8fm239622    13200.0
# 3vwd17aj3fm276741    13200.0
# 3vwd17aj4fm201708    13200.0
# 3vwd17aj5fm225953    13200.0
# 3vwd17aj2fm258506    13300.0
# Name: sellingprice, dtype: float64

# %%
df.mmr<30000
# Out:
# 0          True
# 1          True
# 2         False
# 3          True
# 5          True
#           ...
# 558830     True
# 558831     True
# 558833    False
# 558835     True
# 558836     True
# Name: mmr, Length: 524421, dtype: bool

# %%
df.sort_values(by = "condition",ascending = False).head(10) # sort datframe by columns conditionin  in ascending order
# Out:
#             year      make       model         trim         body transmission  \
# 22460 2005-01-01      ford    explorer   4x4 v6 xlt  13611.35881  13611.35881
# 29610 1998-01-01     Honda       Civic           DX        Sedan    automatic
# 8002  2012-01-01     Scion          xB         Base        Wagon    automatic
# 29593 1998-01-01     dodge     caravan  13611.35881  13611.35881    automatic
# 29596 1998-01-01      ford  expedition      4x4 xlt  13611.35881    automatic
# 29601 1998-01-01    Subaru      Legacy      Outback        Wagon       manual
# 29603 1998-01-01  Plymouth      Breeze         Base        Sedan  13611.35881
# 29605 1998-01-01     Honda       Civic           LX        Sedan  13611.35881
# 29606 1998-01-01    Jaguar   XJ-Series         XJ8L        Sedan    automatic
# 29607 1998-01-01   Lincoln    Town Car    Executive        Sedan    automatic
#
#                      vin state    condition  odometer        color  \
# ...

# %%
df[df['make'].isin(['BMW'])].head()
# Out:
#          year make     model        trim   body transmission  \
# 2  2014-01-01  BMW  3 Series  328i SULEV  Sedan    automatic
# 21 2014-01-01  BMW  5 Series        528i  Sedan    automatic
# 37 2014-01-01  BMW  3 Series  328i SULEV  Sedan    automatic
# 39 2014-01-01  BMW  3 Series  328i SULEV  Sedan    automatic
# 71 2014-01-01  BMW        X1   sDrive28i    SUV    automatic
#
#                   vin state  condition  odometer  color interior  \
# 2   wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 21  wba5a5c51ed501631    ca       29.0   25969.0  black    black
# 37  wba3c1c50ek108497    ca        5.0     111.0  black        —
# 39  wba3c1c58ek106688    ca       45.0    9027.0  white    black
# 71  wbavm1c53evw47779    ca       48.0   19689.0  white    black
#
#                                     seller      mmr  sellingprice  \
# 2   financial services remarketing (lease)  31900.0       30000.0
# 21  financial services remarketing (lease)  34200.0       30000.0
# ...

# %% [markdown]
# ## **Data visualization**

# %%
# Grouping by 'make' column and counting the occurrences of each make
make_counts = df['make'].value_counts().head(10)

# Plotting a bar chart
plt.figure(figsize=(10, 6))     
make_counts.plot(kind='bar')
plt.title('Distribution of Car Makes')
plt.xlabel('Car Make')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotating x-axis labels for better readability
plt.grid(axis='y')  # Adding gridlines along the y-axis
plt.show()

# %%
# Price vs. Odometer
plt.scatter(df['odometer'], df['sellingprice'],marker = '*',color = "g") # scatter plot are used to visualize the relationship 
# between two variable
plt.title('Price vs. Odometer')
plt.xlabel('Odometer')
plt.ylabel('Selling Price')
plt.show()

# %%
body_counts = data_frame['make'].value_counts().head(10)  
plt.figure(figsize=(8, 7))
plt.pie(body_counts, labels=body_counts.index, autopct='%1.1f%%', startangle=25)
plt.title('Distribution of Car make Types')
plt.show()

# %%
plt.figure(figsize = (13,7))
sns.countplot(data = df.head(20) ,x = 'sellingprice', hue = 'transmission')
# Out:
# <Axes: xlabel='sellingprice', ylabel='count'>

# %%
plt.figure(figsize=(13,6))
sns.countplot(data = df , x = 'interior',hue = 'year')
# Out:
# <Axes: xlabel='interior', ylabel='count'>

# %%
sns.histplot(data = df,x = 'sellingprice')
# Out:
# <Axes: xlabel='sellingprice', ylabel='Count'>

# %%
# plt.figure(figsize = (13,7))
# sns.barplot(data = df,x = 'sellingprice',y = 'mmr')

# %%
plt.figure(figsize =(12,7))
sns.barplot(data = df.head(50),x = 'make',y = 'sellingprice')
# Out:
# <Axes: xlabel='make', ylabel='sellingprice'>

# %%
plt.figure(figsize =(12,6))
sns.relplot(x = df['odometer'],y = df['sellingprice'],hue = df['year'],style = df['year'])

# %%
df.to_csv("An_In-Depth_Analysis_of_Car_Pricing_Data.csv",index = False)

# %%
plt.figure(figsize =(12,6))
sns.barplot(data = df,x = 'transmission',y = 'sellingprice')
# Out:
# <Axes: xlabel='transmission', ylabel='sellingprice'>

# %%
sns.barplot(data = df,x = 'odometer',y = 'sellingprice')

# %%
plt.figure(figsize =(14,5))
df['make'].value_counts().plot(kind='bar')
plt.title('Number of Cars per Make')
plt.xlabel('Make')
plt.ylabel('Count')
plt.show()

# %%
df['sellingprice'].plot(kind='hist', bins=30,color = 'lightpink')
plt.title('Distribution of Selling Prices')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.show()

# %%
df.boxplot(column='sellingprice', by='condition')
plt.title('Selling Price by Condition')
plt.xlabel('Condition')
plt.ylabel('Selling Price')
plt.show()

# %%
df['body'].head(20).value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Cars by Body Type')
plt.ylabel('')
plt.show()

# %%
sns.violinplot(x='state', y='sellingprice', data=df)
plt.title('Selling Price Distribution by State')
plt.xlabel('State')
plt.ylabel('Selling Price')
plt.show()

# %%
sns.pairplot(df[['year', 'odometer', 'sellingprice']])
plt.show()

# %%
plt.figure(figsize = (13,6))
sns.countplot(x='transmission', data=df)
plt.title('Count of Cars by Transmission Type')
plt.xlabel('Transmission')
plt.ylabel('Count')
plt.show()

# %%
top_states = df["state"].value_counts().head(10) #.value_counts --> use to count the occurrences of unique values in a columns
top_states.plot(kind ="line",color ='b',marker ='*')
plt.title('Distribution of State',color ='b')
plt.xlabel('State',color = 'r')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## **Build model**

# %%
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('An_In-Depth_Analysis_of_Car_Pricing_Data.csv')

# %%
data.head()
# Out:
#    year    make     model        trim   body transmission                vin  \
# 0  2015     Kia   Sorento          LX    SUV    automatic  5xyktca69fg566472
# 1  2015     Kia   Sorento          LX    SUV    automatic  5xyktca69fg561319
# 2  2014     BMW  3 Series  328i SULEV  Sedan    automatic  wba3c1c51ek116351
# 3  2015   Volvo       S60          T5  Sedan    automatic  yv1612tb4f1310987
# 4  2015  Nissan    Altima       2.5 S  Sedan    automatic  1n4al3ap1fn326013
#
#   state  condition  odometer  color interior  \
# 0    ca        5.0   16639.0  white    black
# 1    ca        5.0    9393.0  white    beige
# 2    ca       45.0    1331.0   gray    black
# 3    ca       41.0   14282.0  white    black
# 4    ca        1.0    5554.0   gray    black
#
#                                               seller      mmr  sellingprice  \
# 0                            kia motors america  inc  20500.0       21500.0
# ...

# %%
data['interior'].nunique()
# Out:
# 18

# %%
dataf = df.drop(['saledate','model','trim','vin','state','color','seller'], axis=1, errors='ignore')

# %%
dataf.head()
# Out:
#                                year    make   body transmission  condition  \
# saledate
# 1970-01-01 00:00:00.000013611  2015     Kia    SUV    automatic        5.0
# 1970-01-01 00:00:00.000013611  2015     Kia    SUV    automatic        5.0
# 1970-01-01 00:00:00.000013611  2014     BMW  Sedan    automatic       45.0
# 1970-01-01 00:00:00.000013611  2015   Volvo  Sedan    automatic       41.0
# 1970-01-01 00:00:00.000013611  2015  Nissan  Sedan    automatic        1.0
#
#                                odometer interior      mmr  sellingprice
# saledate
# 1970-01-01 00:00:00.000013611   16639.0    black  20500.0       21500.0
# 1970-01-01 00:00:00.000013611    9393.0    beige  20800.0       21500.0
# 1970-01-01 00:00:00.000013611    1331.0    black  31900.0       30000.0
# 1970-01-01 00:00:00.000013611   14282.0    black  27500.0       27750.0
# 1970-01-01 00:00:00.000013611    5554.0    black  15350.0       10900.0

# %%
plt.scatter(dataf.mmr,dataf.sellingprice)
plt.xlabel('mmr')
plt.ylabel('sellingprice')
# Out:
# Text(0, 0.5, 'sellingprice')

# %%
dataf.isnull().sum()
# Out:
# year            0
# make            0
# body            0
# transmission    0
# condition       0
# odometer        0
# interior        0
# mmr             0
# sellingprice    0
# dtype: int64

# %%
sns.boxplot(dataf)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
import datetime
